# %% [markdown]
# # Análisis Exploratorio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/training_data.csv')
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2017-01-03  2251.570068  2263.879883  2245.129883  2257.830078
# 1  2017-01-04  2261.600098  2272.820068  2261.600098  2270.750000
# 2  2017-01-05  2268.179932  2271.500000  2260.449951  2269.000000
# 3  2017-01-06  2271.139893  2282.100098  2264.060059  2276.979980
# 4  2017-01-09  2273.590088  2275.489990  2268.899902  2268.899902
#
#      Adj Close      Volume  d_volatility    VIX
# 0  2257.830078  3770530000      0.008328  12.85
# 1  2270.750000  3764890000      0.004961  11.85
# 2  2269.000000  3761820000      0.004872  11.67
# 3  2276.979980  3339890000      0.007943  11.32
# 4  2268.899902  3217610000      0.002899  11.56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1247 non-null   object
#  1   Open          1247 non-null   float64
#  2   High          1247 non-null   float64
#  3   Low           1247 non-null   float64
#  4   Close         1247 non-null   float64
#  5   Adj Close     1247 non-null   float64
#  6   Volume        1247 non-null   int64
#  7   d_volatility  1247 non-null   float64
#  8   VIX           1247 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 87.8+ KB

# %%
df.set_index('Date').iloc[:,1:7].plot(subplots=True, color='blue', figsize=(20,10))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %% [markdown]
# # ¿ Análisis de la serie de tiempo?
#
# No vale la pena descomponer la serie de tiempo. LSTM toma en cuenta seasonality, estacionariedad, etc.
